# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

#pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("HR RAW DATA.csv", index_col=0)

df.head(2)
# Out:
#   Age Attrition BusinessTravel DailyRate Department  DistanceFromHome  \
# 0  51        No            NaN    684,0$        NaN                 6
# 1  52        No            NaN    699,0$        NaN                 1
#
#    Education EducationField  employeecount employeenumber  \
# 0          3            NaN              1          162,0
# 1          4  Life Sciences              1          259,0
#
#    EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  JobLevel  \
# 0                        1       0         51               3         5
# 1                        3       0         65               2         5
#
#                JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# 0   resEArch DIREcToR                 3           NaN       19537,0
# 1             ManAGeR                 3           NaN       19999,0
#
#    MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# 0         6462                   7      Y       No                 13
# ...

# %%
column_to_move = df['employeenumber']

# %%
df.drop(columns='employeenumber', inplace=True)

# %%
df.insert(0, "employeenumber", column_to_move )

# %%
df.sample(2)
# Out:
#     employeenumber Age Attrition BusinessTravel DailyRate Department  \
# 407         1295,0  44       Yes  travel_rarely    621,0$        NaN
# 194          420,0  32        No  travel_rarely    906,0$        NaN
#
#      DistanceFromHome  Education EducationField  employeecount  \
# 407                15          3        Medical              1
# 194                 7          3  Life Sciences              1
#
#      EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  JobLevel  \
# 407                        1  Female         73               3         3
# 194                        4    Male         91               2         2
#
#                          JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# 407   hEALtHcARE rePrESeNtATIve                 4       Married           NaN
# 194             SalEs eXEcuTIVE                 3       Married           NaN
#
#      MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# ...

# %%
for item in df['MaritalStatus']:
        df['MaritalStatus'].replace('Marreid', 'Married', inplace=True)
        df['MaritalStatus'].replace('divorced', 'Divorced', inplace=True)

# %%
df['MaritalStatus'].unique()
# Out:
# array([nan, 'Married', 'Divorced', 'Single'], dtype=object)

# %%
for item in df['Gender']:
    df['Gender'].replace(0, 'Male', inplace=True)
    df['Gender'].replace(1, 'Female', inplace=True)

# %%
 df['Gender']
# Out:
# 0         Male
# 1         Male
# 2         Male
# 3       Female
# 4       Female
#          ...
# 1609      Male
# 1610      Male
# 1611      Male
# 1612      Male
# 1613      Male
# Name: Gender, Length: 1614, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1614 entries, 0 to 1613
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   employeenumber            1183 non-null   object
#  1   Age                       1614 non-null   object
#  2   Attrition                 1614 non-null   object
#  3   BusinessTravel            842 non-null    object
#  4   DailyRate                 1614 non-null   object
#  5   Department                302 non-null    object
#  6   DistanceFromHome          1614 non-null   int64
#  7   Education                 1614 non-null   int64
#  8   EducationField            869 non-null    object
#  9   employeecount             1614 non-null   int64
#  10  EnvironmentSatisfaction   1614 non-null   int64
#  11  Gender                    1614 non-null   object
#  12  HourlyRate                1614 non-null   object
#  13  JobInvolvement            1614 non-null   int64
# ...

# %%
df['Over18'].unique()
# Out:
# array(['Y', nan], dtype=object)
