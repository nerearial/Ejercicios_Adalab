# %% [markdown]
# ### Enlace del ejercicio:
#
# https://books.adalab.es/materiales-promo-b-pt-data-analytics/modulo-3-transformando-datos/repasos/repaso-i

# %%
# Importación de librerías:

import pandas as pd
import numpy as np

# Configuración de display de columnas:

pd.set_option=("display.max_columns", None)

# %%
# Cargamos el archivo

df = pd.read_json("../Files/spaceX_Lunch.json")

# Para comprobar que ser carga bien, hacemos un head:

df.head(2)
# Out:
#                                             fairings  \
# 0  {'reused': False, 'recovery_attempt': False, '...
# 1  {'reused': False, 'recovery_attempt': False, '...
#
#                                                links  \
# 0  {'patch': {'small': 'https://images2.imgbox.co...
# 1  {'patch': {'small': 'https://images2.imgbox.co...
#
#        static_fire_date_utc  static_fire_date_unix    net  window  \
# 0  2006-03-17T00:00:00.000Z           1.142554e+09  False     0.0
# 1                      None                    NaN  False     0.0
#
#                      rocket  success  \
# 0  5e9d0d95eda69955f709d1eb      0.0
# 1  5e9d0d95eda69955f709d1eb      0.0
#
#                                             failures  \
# 0  [{'time': 33, 'altitude': None, 'reason': 'mer...
# 1  [{'time': 301, 'altitude': 289, 'reason': 'har...
#
#                                              details  ...  \
# 0   Engine failure at 33 seconds and loss of vehicle  ...
# ...

# %% [markdown]
# ## EDA

# %%
# Otro método para comprobar los datos:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fairings               169 non-null    object
#  1   links                  205 non-null    object
#  2   static_fire_date_utc   121 non-null    object
#  3   static_fire_date_unix  121 non-null    float64
#  4   net                    205 non-null    bool
#  5   window                 117 non-null    float64
#  6   rocket                 205 non-null    object
#  7   success                186 non-null    float64
#  8   failures               205 non-null    object
#  9   details                134 non-null    object
#  10  crew                   205 non-null    object
#  11  ships                  205 non-null    object
#  12  capsules               205 non-null    object
#  13  payloads               205 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['fairings', 'links', 'static_fire_date_utc', 'static_fire_date_unix',
#        'net', 'window', 'rocket', 'success', 'failures', 'details', 'crew',
#        'ships', 'capsules', 'payloads', 'launchpad', 'flight_number', 'name',
#        'date_utc', 'date_unix', 'date_local', 'date_precision', 'upcoming',
#        'cores', 'auto_update', 'tbd', 'launch_library_id', 'id'],
#       dtype='object')

# %%
df.describe(include="object").T
# Out:
#                      count unique  \
# fairings               169     38
# links                  205    191
# static_fire_date_utc   121    121
# rocket                 205      3
# failures               205      6
# details                134    133
# crew                   205      9
# ships                  205     90
# capsules               205     22
# payloads               205    192
# launchpad              205      4
# name                   205    205
# date_utc               205    199
# date_local             205    200
# date_precision         205      3
# cores                  205    191
# launch_library_id       72     72
# id                     205    205
#
#                                                                     top freq
# fairings              {'reused': None, 'recovery_attempt': None, 're...   61
# links                 {'patch': {'small': None, 'large': None}, 'red...   15
# ...

# %%
df["crew"].value_counts()
# Out:
# crew
# []                                                                                                                                                                                                                                                                197
# [{'crew': '5ebf1a6e23a9a60006e03a7a', 'role': 'Joint Commander'}, {'crew': '5ebf1b7323a9a60006e03a7b', 'role': 'Commander'}]                                                                                                                                        1
# [{'crew': '5f7f1543bf32c864a529b23e', 'role': 'Mission Specialist 2'}, {'crew': '5f7f158bbf32c864a529b23f', 'role': 'Mission Specialist 1'}, {'crew': '5f7f15d5bf32c864a529b240', 'role': 'Pilot'}, {'crew': '5f7f1614bf32c864a529b241', 'role': 'Commander'}]      1
# ...

# %%
lista_cols = df.columns

for col in lista_cols:
    print(f'Para la columna {col} las frecuencias son: {display(df[col].value_counts().reset_index().head())}')
# Out:
#                                             fairings  count
# 0  {'reused': None, 'recovery_attempt': None, 're...     61
# 1  {'reused': False, 'recovery_attempt': False, '...     49
# 2  {'reused': False, 'recovery_attempt': True, 'r...      9
# 3  {'reused': None, 'recovery_attempt': True, 're...      3
# 4  {'reused': False, 'recovery_attempt': True, 'r...      3
# Para la columna fairings las frecuencias son: None
#                                                links  count
# 0  {'patch': {'small': None, 'large': None}, 'red...     15
# 1  {'patch': {'small': 'https://images2.imgbox.co...      1
# 2  {'patch': {'small': 'https://images2.imgbox.co...      1
# 3  {'patch': {'small': 'https://images2.imgbox.co...      1
# 4  {'patch': {'small': 'https://images2.imgbox.co...      1
# Para la columna links las frecuencias son: None
#        static_fire_date_utc  count
# 0  2006-03-17T00:00:00.000Z      1
# 1  2018-07-18T21:00:00.000Z      1
# 2  2020-04-17T11:48:00.000Z      1
# ...

# %%
# Estimamos eliminar las columnas "net" y "tbd":

df.drop(columns = ['net','tbd'], axis = 1, inplace=True)

df.columns
# Out:
# Index(['fairings', 'links', 'static_fire_date_utc', 'static_fire_date_unix',
#        'window', 'rocket', 'success', 'failures', 'details', 'crew', 'ships',
#        'capsules', 'payloads', 'launchpad', 'flight_number', 'name',
#        'date_utc', 'date_unix', 'date_local', 'date_precision', 'upcoming',
#        'cores', 'auto_update', 'launch_library_id', 'id'],
#       dtype='object')

# %%
# Por otro lado, la columna "fairings" es un diccionario con varios datos. Procedemos a separarlas:

col_fairings = df['fairings']

for col in col_fairings:
    print(col)
    break
# Out:
# {'reused': False, 'recovery_attempt': False, 'recovered': False, 'ships': []}

# %%
# Dividimos la columna 'fairings' en otras columnas:

df[["reused", "recovery_attempt", "recovered", "ships_2"]] = df["fairings"].apply(pd.Series).iloc[:, :4]

# %%
df.columns
# Out:
# Index(['fairings', 'links', 'static_fire_date_utc', 'static_fire_date_unix',
#        'window', 'rocket', 'success', 'failures', 'details', 'crew', 'ships',
#        'capsules', 'payloads', 'launchpad', 'flight_number', 'name',
#        'date_utc', 'date_unix', 'date_local', 'date_precision', 'upcoming',
#        'cores', 'auto_update', 'launch_library_id', 'id', 'reused',
#        'recovery_attempt', 'recovered', 'ships_2'],
#       dtype='object')

# %%
df.drop(labels="fairings", axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['links', 'static_fire_date_utc', 'static_fire_date_unix', 'window',
#        'rocket', 'success', 'failures', 'details', 'crew', 'ships', 'capsules',
#        'payloads', 'launchpad', 'flight_number', 'name', 'date_utc',
#        'date_unix', 'date_local', 'date_precision', 'upcoming', 'cores',
#        'auto_update', 'launch_library_id', 'id', 'reused', 'recovery_attempt',
#        'recovered', 'ships_2'],
#       dtype='object')

# %%
# Tratamiento de nulos:

df.isna().sum()
# Out:
# links                      0
# static_fire_date_utc      84
# static_fire_date_unix     84
# window                    88
# rocket                     0
# success                    0
# failures                   0
# details                   71
# crew                       0
# ships                     36
# capsules                   0
# payloads                   0
# launchpad                  0
# flight_number              0
# name                       0
# date_utc                   0
# date_unix                  0
# date_local                 0
# date_precision             0
# upcoming                   0
# cores                      0
# auto_update                0
# launch_library_id        133
# id                         0
# reused                   112
# recovery_attempt          98
# recovered                120
# ships_2                   36
# dtype: int64

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# static_fire_date_utc      84
# static_fire_date_unix     84
# window                    88
# details                   71
# ships                     36
# launch_library_id        133
# reused                   112
# recovery_attempt          98
# recovered                120
# ships_2                   36
# dtype: int64

# %%
df["success"].value_counts()
# Out:
# success
# yes       181
# Unknow     19
# no          5
# Name: count, dtype: int64

# %%
dic_succes = {1.0:"yes", 0.0:"no", np.nan:"Unknow"}

df["success"] = df['success'].map(dic_succes)

df["success"].value_counts()
# Out:
# success
# yes       181
# Unknow     19
# no          5
# Name: count, dtype: int64

# %%
df = df.drop(columns="succes")
